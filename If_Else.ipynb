# %%
a=200
b=400
if a > b:
   print("a is greater") #false

# %%
#If condtion is true then value show else nothing will print in if block if not used with else..........

# %%
a=200
b=400
if a > b:
   print("a is greater")
else:
    print("b is greater")
# Out:
# b is greater

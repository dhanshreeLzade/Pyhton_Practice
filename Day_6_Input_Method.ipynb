# %% [markdown]
# # We use to take input from users------------------

# %%
data= input('enter your name :')
print(data)
type(data)
# Out:
# enter your name : tina
# tina
# str

# %%
#because default value for input method is string....

# %%
dat=int(input("put name : "))
print(dat)
type(dat)
# Out:
# put name :  yes
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dat=int(input("put name : "))
#       2 print(dat)
#       3 type(dat)
#
# ValueError: invalid literal for int() with base 10: 'yes'

# %% [markdown]
# ## why error
# #### he int() function expects a string that represents a valid integer (like "123"), but "yes" is not a number.

# %%
data=int(input("kuch toh enter karo :" ))
print(data)
type(data)
# Out:
# kuch toh enter karo : 34
# 34
# int

# %%
data2=[1,2,3,4]
new_value=[float(input("do point vale numbers :"))]
data2.append(new_value)
print(data2)
# Out:
# do point vale numbers : 56
# [1, 2, 3, 4, [56.0]]

# %%
#created nested list because we have given square brackets to that input

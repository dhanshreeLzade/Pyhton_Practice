# %% [markdown]
# # A dictionary in Python is a collection of key-value pairs, where each key is unique
# # Dictionaries are unordered, mutable, allows duplicates .
# # Unordered (before Python 3.7), ordered from Python 3.7+.
# # Mutable → you can change, add, or remove items

# %%
a={"key":"value","key2":"value2",}
print(type(a))
# Out:
# <class 'dict'>

# %%
b={1:"wwe",1:"word",1:89} ## Keys → unique and immutable Values
print(b)
#Keys must be unique.
#If duplicates are written, Python keeps the last value.
# Out:
# {1: 89}

# %% [markdown]
# # Creating dictionaries

# %%
a=dict(a=1, b=2) #dict constructor
b={1:"maisha"}#simple dictionary
print(a)
b
# Out:
# {'a': 1, 'b': 2}
# {1: 'maisha'}

# %% [markdown]
# # Accssesing elements/items
# # syntax
# #  get().get() Using  (safer, no KeyError if key missing):
# #  dic_name[][][] will give error if key not found
# # keys()
# # values()
# # d.keys() → returns all keys
# # d.values() → returns all values
# # d.items() → returns key-value pairs as tuples
# # ny_office = f["locations"].get("NY")

# %%
squares = {x: x**2 for x in range(5)}
print(squares)  # {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
dict.update(other_dict)	Adds/updates key-value pairs from another dict
dict.copy()	Shallow copy of dict

# %%
d={1:5,2:7}
d2={2:8,3:9}
d.update(d2)
d
# Out:
# {1: 5, 2: 8, 3: 9}

# %%
d = {"name": "Alice", "age": 20}
# error d[3]
#print(d["name"])   # Alice
print(d["age"])
# Out:
# 20

# %%
f = {"name":"TechCorp","CEO":"Alice","employees":350,"locations":["NY","London","Tokyo"],"public":True}
f["locations"][1]
#dictionary made index nahi key work ok
#list mdhe index work hote
# Out:
# 'London'

# %%
f = { "name": "TechCorp","CEO": "Alice","employees": 350,"locations": {"NY": "New York Office","London": "London Office",}}
f["locations"]["NY"]
f["locations"]["london"] #key error in this way
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 3
#       1 f = { "name": "TechCorp","CEO": "Alice","employees": 350,"locations": {"NY": "New York Office","London": "London Office",}}
#       2 f["locations"]["NY"]
# ----> 3 f["locations"]["london"]
#
# KeyError: 'london'

# %%
f = { "name": "TechCorp","CEO": "Alice","employees": 350,"locations": {"NY": "New York Office","London": "London Office",}}
print(f["locations"]["NY"])
f["locations"]["London"]
# Out:
# New York Office
# 'London Office'

# %%
# Using get() (safer, no KeyError if key missing):
f = { "name": "TechCorp","CEO": "Alice","employees": 350,"locations": {"NY": "New York Office","London": "London Office",}}
print(f.get("locations").get("London"))#no key error even if values is not there
a=f["locations"].get("London")
#syntax get().get()
#syntax dic_name[][][]
a
# Out:
# London Office
# 'London Office'

# %% [markdown]
# # Adding or updating elements

# %%
d = {"name": "Alice"}
d["age"] = 20          # add new key-value
d["name"] = "Bob"      # update existing key
d["birth"]="hinganghat"
d.update({1:"stir",2:"meena"}) #Using keyword arguments (keys must be strings):
d.update(one="stir", two="meena") #key without "" in update
d
# Out:
# {'name': 'Bob',
#  'age': 20,
#  'birth': 'hinganghat',
#  1: 'stir',
#  2: 'meena',
#  'one': 'stir',
#  'two': 'meena'}

# %% [markdown]
# # Removing items

# %%
#Method	Description	Example
#pop(key)	Removes key & returns value	d.pop("age")
#popitem()	Removes last inserted item (Python 3.7+)	d.popitem()
del d[key]	Deletes a key	del d["name"]
clear()	Removes all items	d.clear()

# %% [markdown]
# # pop()
# ### Deletes a key from the dictionary.
# ###  return the value.
# ### Can provide a default value if the key doesn’t exist (prevents error).

# %%
f = { "name": "TechCorp",2:"hee"}#one key one value no more than that
print(f.pop(2))#deleted key and print value but in actual deletes key and value both
f
# Out:
# hee
# {'name': 'TechCorp'}

# %% [markdown]
#  # popitem()

# %%
f = { "name": "TechCorp","CEO": "Alice","employees": 350,}
f.popitem() #dict.popitem() takes no arguments (1 given)
f
# Out:
# {'name': 'TechCorp', 'CEO': 'Alice'}

# %% [markdown]
# # del d[key]
# ### Deletes a key from the dictionary.
# ### Does NOT return the value.
# ### Throws KeyError if the key doesn’t exist.

# %%
v = { "name": "TechCorp","CEO": "Alice","employees": 350,}
del v["name"]
v
#detletes key and value both have to pass key else invalid syntax
# Out:
# {'CEO': 'Alice', 'employees': 350}

# %% [markdown]
# # clear()

# %%
clear()
Removes all items
d.clear()

# %%
v.clear()
v
# Out:
# {}

# %% [markdown]
# # 3️⃣ Checking membership
# # key in d → True if key exists
# # key not in d → True if key doesn’t exist

# %%
len(a)
# Out:
# 2

# %%
a.items() #To know the items in dictionary will give result in list
# Out:
# dict_items([('key', 'value'), ('key2', 'value2')])

# %%
a["key2"] # We dont use indexing in dictionary we use key to acssess elements......
# Out:
# 'value2'

# %%
a.keys() # to acssess  all  keys

# %%
a.values()  to  acssess all values
# Out:
# dict_values(['value', 'value2'])

# %%
b={1:"aishwarya",2:"jenny",3:"minakshi washing powder"}

# %%
print(b)
# Out:
# {1: 'aishwarya', 2: 'jenny', 3: 'minakshi washing powder'}

# %%
b.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
b.items()
# Out:
# dict_items([(1, 'aishwarya'), (2, 'jenny'), (3, 'minakshi washing powder')])

# %%
b.values()
b[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 3
#       1 b.values()
#       2 b[2]
# ----> 3 b["jenny"]
#
# KeyError: 'jenny'

# %%
car={"brand":"audi","modelNo":"MH678","clr":"black","price":353800}

# %%
print(car)
# Out:
# {'brand': 'audi', 'modelNo': 'MH678', 'clr': 'black', 'price': 353800}

# %%
car[brand] #have to use ""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 car[brand]
#
# NameError: name 'brand' is not defined

# %%
car["brand"]
# Out:
# 'audi'

# %%
car["brand"]
# Out:
# 'audi'

# %%
car["brand"]="mercedes" #Replces value

# %%
print(car)
# Out:
# {'brand': 'mercedes', 'modelNo': 'MH678', 'clr': 'black', 'price': 353800}

# %%
car["rel_year"]=2004

# %%
print(car)
# Out:
# {'brand': 'mercedes', 'modelNo': 'MH678', 'clr': 'black', 'price': 353800, 'rel_year': 2004}

# %%
car.pop("rel_year")
# Out:
# 2004

# %%
print(car)
# Out:
# {'brand': 'mercedes', 'modelNo': 'MH678', 'clr': 'black', 'price': 353800}

# %%
x=car.copy()

# %%
print(x)
# Out:
# {'brand': 'mercedes', 'modelNo': 'MH678', 'clr': 'black', 'price': 353800}

# %%
key=[1,2,3,4,5,6]
d= dict.fromkeys(key,"aishwarya")

# %%
print(d)
# Out:
# {1: 'aishwarya', 2: 'aishwarya', 3: 'aishwarya', 4: 'aishwarya', 5: 'aishwarya', 6: 'aishwarya'}

# %%
car.get("brand")
# Out:
# 'mercedes'

# %%
car.get("ser_num","MH676")
# Out:
# 'MH676'

# %%
print(car)
# Out:
# {'brand': 'mercedes', 'modelNo': 'MH678', 'clr': 'black', 'price': 353800}

# %%
a={"name":"mangesh"}
print(a)
# Out:
# {'name': 'mangesh'}

# %%
a.setdefault("age",23)
# useful when you want to:
#Add a key only if it doesn’t already exist
#Avoid overwriting existing values
#Initialize lists or counters inside dictionaries
# Out:
# 23

# %%
a.update({"surname":"sambhare","passoutyear":2024})

# %%
print(a)
# Out:
# {'name': 'mangesh', 'age': 23, 'surname': 'sambhare', 'passoutyear': 2024}

# %%
a.values()
# Out:
# dict_values(['mangesh', 23, 'sambhare', 2024])

# %%
a.get("age")
# Out:
# 23

# %%
a["age"]
# Out:
# 23

# %%
a={1:"apple"} #To mixed these two dictionaries
b={2:"banana"}
c=a|b #union operation
c
# Out:
# {1: 'apple', 2: 'banana'}

# %%
dic1={1:"ananaya",2 :{3:"hello"},3:{4:"minakshi"}}

# %%
print(dic1)
# Out:
# {1: 'ananaya', 2: {3: 'hello'}, 3: {4: 'minakshi'}}

# %%
print(dic1[2][3])
# Out:
# hello

# %%
print(a.get(2).get(3))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 print(a.get(2).get(3))
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %%
dic2= {"A":{"B":34, "C":{"D":90},"F":89,"45":{6:{45:8}}}}
print(dic2)
# Out:
# {'A': {'B': 34, 'C': {'D': 90}, 'F': 89, '45': {6: {45: 8}}}}

# %%
dic2[A][B]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 dic2[A][B]
#
# NameError: name 'A' is not defined

# %%
dic2["A"]["B"]
# Out:
# 34

# %%
dic2["A"]["45"]
# Out:
# {6: {45: 8}}

# %%
dic2["A"]["45"][6]
# Out:
# {45: 8}

# %%
dic2["A"]["45"][6][45]
# Out:
# 8

# %%
dic2.get(6)

# %%
print(dic2)
# Out:
# {'A': {'B': 34, 'C': {'D': 90}, 'F': 89, '45': {6: {45: 8}}}}

# %%
#-try to access 234 out of this list

# %%
list1 = [3,4,5,6,7 , [23,456,67,8,78,78] , [345,56,87,8,98,9] , (234,6657,6) , {"key1" :"sudh" , 234:[23,45,656]}]
list1[7][0]
# Out:
# 234

# %%
#-try to access 456

# %%
list1[5][1]
# Out:
# 456

# %%
#-Try to extract only a list collection form list l

# %%
for item in list1:
    if type(item) is list:
       print(item)
print(item)
# Out:
# [23, 456, 67, 8, 78, 78]
# [345, 56, 87, 8, 98, 9]
# {'key1': 'sudh', 234: [23, 45, 656]}

# %%
#-Try to extract "sudh"

# %%
list1["key1"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 list1["key1"]
#
# TypeError: list indices must be integers or slices, not str

# %%
list1[8]
# Out:
# {'key1': 'sudh', 234: [23, 45, 656]}

# %%
list1[8]["key1"]
# Out:
# 'sudh'

# %%
# Try to list all the key in dict element avaible in list
list1 = [3,4,5,6,7 , [23,456,67,8,78,78] , [345,56,87,8,98,9] , (234,6657,6) , {"key1" :"sudh" , 234:[23,45,656]}]
keys=[]
for item in list1:
    if type(item)==dict:
        keys += item 
print(keys)
# Out:
# ['key1', 234]

# %%
list1[8].keys()
# Out:
# dict_keys(['key1', 234])

# %%
list1 = [3,4,5,6,7 , [23,456,67,8,78,78] , [345,56,87,8,98,9] , (234,6657,6) , {"key1" :"sudh" , 234:[23,45,656]}]
print(list1[5:7]+list1[8][234])
# Out:
# [[23, 456, 67, 8, 78, 78], [345, 56, 87, 8, 98, 9]]
# [[23, 456, 67, 8, 78, 78], [345, 56, 87, 8, 98, 9], 23, 45, 656]

# %%
# -Try to extract all the value element form dict available in list

# %%
list1[8].values()
# Out:
# dict_values(['sudh', [23, 45, 656]])

# %% [markdown]
# # -Try to extract only total number of  elemets in list collection form list l

# %%
l = [3,4,5,6,7 , [23,456,67,8,78,78] , [345,56,87,8,98,9] , (234,6657,6) , {"key1" :"sudh" , 234:[23,45,656]}]

# %%
len(l)
print(len(l[5]))
print(len(l[6]))
print(len(l[8][234]))
# Out:
# 6
# 6
# 3

# %% [markdown]
# # Access the nested key increment from the following dictionary
# Access 12
# emp_dict = {
#     "company": {
#         "employee": {
#             "name": "Jess",
#             "payable": {
#                 "salary": 9000,
#                 "increment": 12
#             }
#         }
#     }
# }

# %%
emp_dict = {"company": {"employee": {"name": "Jess","payable": {"salary": 9000,"increment": 12 }}}}
emp_dict["company"]["employee"]["payable"]["increment"]
# Out:
# 12

# %% [markdown]
# # take integer as input and print its square as output

# %%
num=int(input("enter the number"))
print(num*num)
# Out:
# enter the number 3
# 9

# %% [markdown]
# # Accept registeration number of vehical as input and print its state code as output

# %%
registeration_number=input("enter the registeration number: ")
state_code=registeration_number[: 2]
print(state_code)
# Out:
# enter the registeration number:  MH456789
# MH

# %% [markdown]
# # ) Accept five words as input and print the sentence formed by these words after adding a space between consecutive words and a full stop at the end.

# %%
word1=input("enter the word: ")
word2=input("enter the word: ")
word3=input("enter the word: ")
word4=input("enter the word: ")
word5=input("enter the word: ")
sentence= word1 +" "+word2+" "+word3+" "+ word4 +" "+word5
print(sentence)
# Out:
# enter the word:  hi
# enter the word:  my
# enter the word:  name
# enter the word:  is
# enter the word:  meena
# hi my name is meena

# %% [markdown]
# # )  Accept the date in DD-MM-YYYY format as input and print the year as output

# %%
whole_date=input("enter date in DD-MM-YYYY format : ")
#It is ONE single string:
#"25-11-2025"
day,month,year=whole_date.split('-')
#You must manually split the string by the - character. - then only python can know which is day month and year else it is just a string for it..
print(year)
# Out:
# enter date in DD-MM-YYYY format :  23-11-2002
# 2002

# %%
whole_date=input("enter date in DD-MM-YYYY format : ")
print(whole_date[6:])
# Out:
# enter date in DD-MM-YYYY format :  12-11-2002
# 2002

# %% [markdown]
# # Accept five words as input and print the sentence formed by these words after adding a space between consecutive words and a full stop at the end.

# %%
# Take input of 5 words separated by spaces
a1, b1, c1, d1, e1 = input("Enter five words separated by spaces: ").split()
# Form the sentence with spaces
sentence = a1 + " " + b1 + " " + c1 + " " + d1 + " " + e1
# Print sentence with a period
print(sentence + ".")
# Out:
# enter five words : himynaeis aish
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[300], line 1
# ----> 1 a1,b1,c1,d1,e1=input("enter five words :")
#       2 sentence=a1+b1+c1+d1+e1
#       3 print(sentence+".")
#
# ValueError: too many values to unpack (expected 5)

# %%
a1=input("enter five words :")
b1=input("enter five words :")
c1=input("enter five words :")
d1=input("enter five words :")
e1=input("enter five words :")
sentence=a1+" "+b1+" "+c1+" "+d1+" "+e1
print(sentence+".")
# Out:
# enter five words : hi
# enter five words : how
# enter five words : are
# enter five words : you
# enter five words : there
# hi how are you  there.

# %% [markdown]
# #  Accept a sequence of five single digit numbers separated by commas as input. Print the product of all five numbers.

# %%
a,b,c,d,e=input("enter the number").split(',') #here u need comma as a string---------
product=int(a)*int(b)*int(c)*int(d)*int(e) #converted string into int function(a)
product

# %%
s=input()

a=s.split()#split chya bracket chya andar je lihiti tithun split hote te input mdhe taka lagte
s
a
# Out:
#  hello guyshow r u
# ['hello', 'guyshow', 'r', 'u']

# %% [markdown]
# # min max values from list

# %% [markdown]
# l = [3,4,5,6,7 , [23,456,67,8,78,78] , [345,56,87,8,98,9] , (234,6657,6) , {"key1" :"sudh" , 234:[23,45,656]}]

# %%
l[0:5]
# Out:
# [3, 4, 5, 6, 7]

# %%
print(max(l[0:5]))
print(min(l[0:5]))
# Out:
# 7
# 3

# %% [markdown]
# # How many items are in the tuple

# %%
l[5]
max(l[5])
min(l[6])

# %%
l = [3, 4, 5, 6, 7, [23, 456, 67, 8, 78, 78], [345, 56, 87, 8, 98, 9], (234, 6657, 6), {'key1': 'sudh', 234: [23, 45, 656]}]
# What are the minimum and maximum values among just the first five integer elements of the list l?
# How many items are in the tuple
#  What is the sum of the first five integers in the list

# %% [markdown]
# # How many items are in the tuple

# %%
l = [3, 4, 5, 6, 7, [23, 456, 67, 8, 78, 78], [345, 56, 87, 8, 98, 9], (234, 6657, 6), {'key1': 'sudh', 234: [23, 45, 656]}]
len(l[7])
# Out:
# 3

# %% [markdown]
# # #  What is the sum of the first five integers in the list

# %%
l = [3, 4, 5, 6, 7, [23, 456, 67, 8, 78, 78], [345, 56, 87, 8, 98, 9], (234, 6657, 6), {'key1': 'sudh', 234: [23, 45, 656]}]
print(sum(l[0:5]))
# Out:
# 25

# %%
List=[1,2.3,"prograam",1]
type(List)
# Out:
# list

# %%
list=[]
print(list)
list = [10, "hello", 3.14]
list[1] # Output: hello
# Out:
# []
# 'hello'

# %%
l=[1,2]
l.clear()

# %%
l
# Out:
# []

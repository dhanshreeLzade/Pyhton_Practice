# %%
# Create a dictionary with keys: name, age, city and print it.
dic={"name":"aish","age":"23","city":"nagpur"}
print(dic)
type(dic)
# Out:
# {'name': 'aish', 'age': '23', 'city': 'nagpur'}
# dict

# %%
d = {'a':10, 'b':20, 'c':30}
#d['b']
print(d.get('b'))
# d.keys()# it takes no arguments
# Out:
# 20

# %%
# Write a program to check if key 'marks' exists in a dictionary.
dic={"name":"aish","age":"23","city":"nagpur",'marks':"hi"}
if 'marks' in dic:
    print("true it is")
else:
    print("false")
# Out:
# true it is

# %%
# How do you add a new key-value pair grade:'A' to a dictionary?
dic['grade']='A'

# %%
print(dic)
# Out:
# {'name': 'aish', 'age': '23', 'city': 'nagpur', 'marks': 'hi', 'grade': 'A'}

# %%
d = {'x':5, 'y':15, 'z':10}
# Find the key with the maximum value (without using max()).
#i is a key, not a value d[i] is value 

num=0
for i in d:
    if d[i]>num:
        num=d[i]
print(num)
# Out:
# 15

# %%
# {'a': 2, 'b': 3, 'c': 2} → print keys with value 2
d={'a': 2, 'b': 3, 'c': 2}
for i in d:
    if d[i]==2:
       print(i,d[i])
# Out:
# a 2
# c 2

# %%
Create a dictionary and print it

Access value using key

Add a new key-value pair

Update value of a key

Delete a key from dictionary

Check if a key exists in dictionary

Print all keys

Print all values

Print key-value pairs

Find length of dictionary

# %%
# Update value of a key
d={'a': 2, 'b': 3, 'c': 2}
d['a']="true"

# %%
print(d)
# Out:
# {'a': 'true', 'b': 3, 'c': 2}

# %%
# Find length of dictionary
len(d)
# Out:
# 3

# %%
#swap
var1=12
var2=22
#swaping
"""var2=var1 #12
var1=var2 #12"""
var1,var2=var2,var1
print(var1,var2)
# Out:
# 22 12

# %%
print("heelo")
# Out:
# heelo

# %%
"""#temporary variable used
temp=var1 #12
var1=var2 #22
var2=temp #12
print(var1,var2)"""
# Out:
# 22 12

# %%
var1=var1+var2
var2=var1-var2
var1=var1-var2
print(var1,var2)
# Out:
# 22 12

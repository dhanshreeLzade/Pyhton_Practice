# %%
✅ 10 NEW Practice Questions for Both Loops
1️⃣ Print all numbers divisible by 3 between 10 and 100.
2️⃣ Count how many characters are NOT vowels in a given string.
3️⃣ Print the sum of digits of a number, but skip digit 5 if it appears.

Example:
45215 → skip 5 → sum = 4 + 2 + 1 = 7

4️⃣ Print factorial, but stop if number becomes greater than 1000.

(Use break)

5️⃣ Print all characters of a string in reverse WITHOUT using slicing.

(Not done earlier)

6️⃣ Ask the user 5 times to enter a number → print only the odd ones.
7️⃣ Count how many times a letter appears in a string.

Example:
String: "banana"
Letter: "a" → Output: 3

8️⃣ Print this pattern (no stars problem done earlier):
1
12
123
1234
12345


(Do using while OR for)

9️⃣ Print the product of all even numbers from 1 to 20.
🔟 Print numbers from 1 to 50, but skip numbers 10 to 20 using continue.

# %%
# 1️⃣ Print all numbers divisible by 3 between 10 and 100.
for i in range(10,101):
    if i%3==0:
        print(i)
# Out:
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %%
# 1️⃣ Print all numbers divisible by 3 between 10 and 100.
num=10
while num <=101:
    if num%3==0:
        print(num)
    num=num+1
# Out:
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99

# %%
# 1️⃣ Print all numbers divisible by 3 between 10 and 100.
i=10
while i <=101:
    i=i+1
    if i%3==0:
        print(i)
# Out:
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99
# 102

# %%
#2️⃣ Count how many characters are NOT vowels in a given string.
string="HIEGHT"
count=0
a=('a','e','i','o','u')
for i in string:
    if i in a:
        count=count+1
print(i,count)
# Out:
# T 0

# %%
#Print the following pattern using loops:
p=1
for i in range(1,5):
    print(i*p)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1, 5):
    print(str(i) * i)
# Out:
# 1
# 22
# 333
# 4444

# %%
for i in range(1, 5):
    print('*' * i)
# Out:
# *
# **
# ***
# ****

# %%
Your doubt:

Why str(i)? Why not just i * i?

Simple reason 👇

Python cannot repeat numbers, it can only repeat strings.

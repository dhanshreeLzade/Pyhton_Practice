# %%
1.Create a tuple with the values: ("apple", "banana", "cherry")
👉 Print the second element.

# %%
tuple_1=("apple", "banana", "cherry")
print(tuple_1[1])
type(tuple_1)
# Out:
# banana
# tuple

# %%
2.Access the last element of a tuple without using an index number directly.

# %%
for item in tuple_1:
    if item=="cherry":
        print("last element is cherry")
# Out:
# last element is cherry

# %%
#when u dont know about the item in last 
for item in tuple_1:
    last=item
print(last)#print these after l
# Out:
# cherry
# 'for item in numbers:\n    item=range(3)\nprint(a)'

# %%
#with slicing
tuple_1[-1:]
# Out:
# ('cherry',)

# %%
#Given a tuple
numbers = (10, 20, 30, 40, 50)
👉 Print the first three elements using slicing. and withou slicng..

# %%
numbers = (10, 20, 30, 40, 50)
print(numbers[:3])
print(numbers[0],numbers[1],numbers[2])
# Out:
# (10, 20, 30)
# 10 20 30

# %%
#without slicing using count
count=0
for item in numbers:
    if count<3:
        print(item)
        count=count+1
    else:
        break
# Out:
# 10
# 20
# 30

# %%
#Find the length of a tuple
num_1=(1,2,3,4,5,6,787878,5)
#len(num_1)
#without using function
count=0
for item in num_1:
    if count<=item:
        count=count+1
    else:
        break
print(count)
# Out:
# 0

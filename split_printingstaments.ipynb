# %%
#split()
var1=input("enter: ")
print(var1)
var2=var1.split()
var2
# Out:
# enter:  hello guys how r u
# hello guys how r u
# ['hello', 'guys', 'how', 'r', 'u']

# %%
var2=var1.split(",")
print(var2)
# Out:
# ['hello guys how r u']

# %%
print("hello")
print("hello",var2)
# Out:
# hello
# hello ['hi my name is aishwarya', ' understood or not']

# %%
print("hello","world")
print("hello","world",sep=",")
# Out:
# hello,world

# %%
a="top separate these we used sep lets see how its run"
print("the output is:",a,sep=",")
print("the output is:",a,sep=" anything here which we need ")
# Out:
# the output is:,top separate these we used sep lets see how its run
# the output is: anything here which we need top separate these we used sep lets see how its run

# %%
#how to print variable in string
print(f"hello world {var1}")#f stand for formated string leteral
# Out:
# hello worldhi my name is aishwarya, understood or not

# %%
print("anything here which we need top separate\n these we used sep lets see how its run")#new line
# Out:
# anything here which we need top separate
#  these we used sep lets see how its run

# %%
print("anything here which we need top separatethese we used sep\n" ,end="lets see how its run")# for next line
# Out:
# anything here which we need top separatethese we used sep
# lets see how its run

# %%
print("anything here which we need top separate\t these we used sep lets see how its run") # for space
# Out:
# anything here which we need top separate	 these we used sep lets see how its run

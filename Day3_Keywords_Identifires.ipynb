# %% [markdown]
# # Keywords
# #### *Keywords are reserved word that cannot be used as an identifires in python.*

# %%
True =12
print (True)
# Out:
#   Cell In[1], line 1
#     True =12
#     ^
# SyntaxError: cannot assign to True

# %% [markdown]
# #### It is not getting print because True is builtIn keyword

# %% [markdown]
# None = 34
# print (None)

# %% [markdown]
# #### It is not getting print because  is None builtIn keyword

# %% [markdown]
# # Identifires
# #### *Identifires are name given to variable , functions , and classes and some other values or elements in the python.*

# %%
def chalo(bus):
    return "hello" + bus
print (chalo("nagpur"))

# %% [markdown]
# #### here chalo is the identifiers.....
# ##### def is keyword....
# ###### bus is a parameter ......

# %%
 def email (input):
     return "Email is" + input
     print (email("aishwaryazade24@gmail.com"))

# %% [markdown]
# ### This is not giving any output because print statement is in function we have take outside of it return keyword already endded or terminated the function

# %%
 def email (input):
     return "Email is " + input
     
 print (email("aishwaryazade24@gmail.com"))
# Out:
# Email is aishwaryazade24@gmail.com

# %% [markdown]
# # Day_1
# ## Variables,Comments, Print_Statement

# %%
#used for comments that is single line comment
#Python is case sensitive language.

# %%
print("hello world") 
"""This syntax is used for multilines comments """ 
print('hi')
# Out:
# hello world
# hi

# %%
a=4
d="hey"
print(d)
# Out:
# hey

# %%
# Out:
# 78
# google

# %%
""" hi """
# Out:
# ' hi '

# %% [markdown]
# #Here we used Heading in an Markdown option we need to give space after #

# %% [markdown]
# # **MARKDOWN HEADING**

# %% [markdown]
# ## Markdown Heading 2

# %%
A1=2
A1
# Out:
# ' hi '

# %%
B1=1
C1=2
B1
C1
# Out:
# 2

# %%
#THE VARIABLE WHICH IS AT END WILL BE PRINT ELSE IN BETWEEN WE HAVE TO USE PRINT STATEMENT

# %%
D1=2
E1=3
"""value should be in 
integer"""
print(E1)
S1=D1+E1
S1
# Out:
# 3
# 5

# %%
9-3
# Out:
# 6

# %%
78-4
# Out:
# 74

# %%
78/4
# Out:
# 19.5

# %%
78//4
# Out:
# 19

# %%
78%2
# Out:
# 0

# %%
L

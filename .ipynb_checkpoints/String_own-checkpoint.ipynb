# %%
#creating string
str="hey there"
print(str)
# Out:
# hey there

# %%
#we can use indexing in string
str[0]
# Out:
# 'h'

# %%
str[-1]
# Out:
# 'e'

# %%
len(str)
# Out:
# 9

# %% [markdown]
# # String slices- A subpart or segment of a string is string slices.......

# %%
str[0:4]
# Out:
# 'hey '

# %%
str[:]
# Out:
# 'hey there'

# %%
# String operations
str1="google"
str2="chrome"
#Concantenation operator +
str1+str2
# Out:
# 'googlechrome'

# %%
# *operation
str1*3 #----------> it reates the string for number of times you put
#note-
#if one of the operand is string then another should be integer
# Out:
# 'googlegooglegoogle'

# %% [markdown]
# # in operator

# %%
'o' in 'google'
# Out:
# True

# %% [markdown]
# # Methods upper,lower,find

# %%
str.upper()
# Out:
# 'HEY THERE'

# %%
str.lower()
# Out:
# 'hey there'

# %%
#This methods returns new strings and take no output

# %%
str.find("y") #--> # it find at what index the character is present
# Out:
# 2

# %%
str.find("z") #--> # it find at what index the character is present if not fount then returns -1
# Out:
# -1

# %%
str.find('be',2) #you can also provide index in find method from where to start
# Out:
# -1

# %% [markdown]
# # Practice problem

# %%
filelist=["file.txt","file2.txt","file.exe"]
for i in filelist:
    if ".txt" in i:
        print(i)
# Out:
# file.txt
# file2.txt

# %% [markdown]
# # String comparision

# %%
word="helloworld"
if word=="banana": # Comparision operator 
    print("true")
else:
    print("false")
# Out:
# false

# %%
# Immutability
str1="rihana"
str1[1]='a' #immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 # Immutability
#       2 str1="rihana"
# ----> 3 str1[1]='a'
#
# TypeError: 'str' object does not support item assignment

# %%
str1="rihana"
str1='z'+str[1]
print(str1)
# Out:
# ze

# %%
str[1]='z'
print(str1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 str[1]='z'
#       2 print(str1)
#
# TypeError: 'str' object does not support item assignment

# %%
s = "Hello"
new = "P" + s[1:] #it starts from index 1 and add p at the front of ello
print(new)
# Out:
# Pello

# %%
✅ Summary
Action	Allowed?	Explanation
Add characters	✅ Yes	Creates new string
Replace	❌ No	Cannot change original
Remove	❌ No	Cannot delete original
Modify	✅ Yes	But only by making a new string

# %%
# list and string ____ list is sequense of values and string is sequence of chracters
str1="NARMADA"
list(str1) #--list break function into individual character
# Out:
# ['N', 'A', 'R', 'M', 'A', 'D', 'A']

# %%
str2="here"
str2.split()
# Out:
# ['here']

# %%
str2="here i am done with assignment"
str2.split()
# Out:
# ['here', 'i', 'am', 'done', 'with', 'assignment']

# %%
#split()--- separate words from sentence

# %% [markdown]
# # ✅ What is a Backslash?
# # Backslash \ is used in strings as an escape character.

# %%
str="heelo\nwolrd" #\n---new line
print(str)
# Out:
# heelo
# wolrd

# %% [markdown]
# # What is Traversing?
# # Traversing a string means going through the string one character at a time.

# %%
word = "AISH"
for ch in word:
    print(ch)
# Out:
# A
# I
# S
# H

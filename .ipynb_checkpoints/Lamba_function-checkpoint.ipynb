# %% [markdown]
# ## Use for small operations perform

# %%
add= lambda a,b :a+b ##a b are arguments then addd

# %%
# Out:
# <function <lambda> at 0x0000021F0B068CC0>

# %%
.upper
.lower
.title
.captitalize()

# %%
lambda arguments : expression

# %%
names=["mosstech","dhanashri"]
print(names)
# Out:
# ['mosstech', 'dhanashri']

# %%
list_upper= lambda a:a.upper()

# %%
list_upper(names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 list_upper(names)
#
# Cell In[9], line 1, in <lambda>(a)
# ----> 1 list_upper= lambda a:a.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
list_upper=list(map(lambda a:a.upper(),names))

# %%
print(list_upper)
# Out:
# ['MOSSTECH', 'DHANASHRI']

# %%
list_upper=list(map(lambda a:len(a)>5,names))

# %%
list_upper
# Out:
# [True, True]

# %%
list_upper=list(filter(lambda a:len(a)>5,names)) #for to print only greater than 5 lengt names

# %%
import datetime
date_time=datetime.datetime.now()
print(date_time)
# Out:
# 2025-12-15 18:57:09.004013

# %%
 day=lambda a:a.day()
print(day(date_time))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 day=lambda a:a.day()
# ----> 2 print(day(date_time))
#
# Cell In[20], line 1, in <lambda>(a)
# ----> 1 day=lambda a:a.day()
#       2 print(day(date_time))
#
# TypeError: 'int' object is not callable

# %%
lambda aruments:expression

# %%
mul=lambda a,b:a*b
print(mul(2,3))
# Out:
# 6

# %%
mul=lambda a,b,c:a*b*c
print(mul(2,3,3))
# Out:
# 18

# %%
mul(23,4,4)
# Out:
# 368

# %%
max_number=lambda a,b:a if a>b else b
print(max_number(2,3))
# Out:
# 3

# %%
list_n=[1,2,3,4,5,6]
var=lambda a:a*2
var
# Out:
# <function __main__.<lambda>(a)>

# %%
list_n=[1,2,3,4,5,6]
var=map(lambda a:a*2)
var
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 list_n=[1,2,3,4,5,6]
# ----> 2 var=map(lambda a:a*2)
#       3 var
#
# TypeError: map() must have at least two arguments.

# %%
list_n=[1,2,3,4,5,6]
var=map(lambda a:a*2,list_n) #here have to put list name because map takes atleast 2 arguments
var

# %%
list_n=[1,2,3,4,5,6]
var=list(map(lambda a:a*2,list_n)) #here have to put list name because map takes atleast 2 arguments
var
# Out:
# [2, 4, 6, 8, 10, 12]

# %%
#filter
list1=[1,2,3,4,5,6,7,8]
var=lambda a:a%2==0,li

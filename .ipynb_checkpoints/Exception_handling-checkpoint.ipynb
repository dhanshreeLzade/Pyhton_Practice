# %%
block --
Keyword	      Meaning
try	          code that may cause error
except	      runs if error occurs
else	      runs if no error
finally	      runs always
raise

# %%
🔹 try block

Definition:
👉 Contains the code that may cause an error.

except block

Definition:
👉 Runs when an exception occurs in the try block.

else block

Definition:
👉 Runs only if no exception occurs in the try block.

Definition:
👉 Always runs, whether exception occurs or not.

# %%
#homework 10 different errors------

# %%
a=9
b=0
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 a=9
#       2 b=0
# ----> 3 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
try:
    a=9
    b=0
    print(a/b)
except ZeroDivisionError:
    print("cannot divide it with zero" )
# Out:
# cannot divide it with zero

# %%
try:
    a="aishwarya"
    b=0
    print(a/b)
except ZeroDivisionError:
    print("cannot divide it with zero" )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2     a="aishwarya"
#       3     b=0
# ----> 4     print(a/b)
#       5 except ZeroDivisionError:
#       6     print("cannot divide it with zero" )
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
try:
    a="aishwarya"
    b=0
    print(a/b)
except Exception as e:
    print(e )
# Out:
# unsupported operand type(s) for /: 'str' and 'int'

# %%
try:
    a="aishwarya"
    b=0
    print(a/b)
except TypeError:
    print("this error ocuured")
# Out:
# this error ocuured

# %%
try:
    a="aishwarya"
    b=0
    print(a/b)
except ZeroDivisionError:
    print("cannot divide it with zero" )
except TypeError:
    print("this error ocuured")
else:
    print("this will execute try block only")
# Out:
# this error ocuured

# %%
try:
    a=5
    b=0
    print(a/b)
except ZeroDivisionError:
    print("cannot divide it with zero" )
except TypeError:
    print("this error ocuured")
else:
    print("this will execute try block only")
# Out:
# cannot divide it with zero

# %%
try:
    a=5
    b=2
    print(a/b)
except ZeroDivisionError:
    print("cannot divide it with zero" )
except TypeError:
    print("this error ocuured")
else:
    print("this will execute try block only")
# Out:
# 2.5
# this will execute try block only

# %%
try:
    print(10 / 2)
except:
    print("Error")
else:
    print("No error happened")

# %%
🟢 EASY LEVEL
1️⃣ Handle division by zero

Write a program that takes two numbers and prints division.
If denominator is zero, print "Cannot divide by zero".

2️⃣ Handle wrong input

Take an integer from user.
If user enters a string, print "Enter valid number".

3️⃣ List index error

Access index 5 from a list of 3 elements.
Handle the exception.

4️⃣ Dictionary key error

Access a key that does not exist in a dictionary.
Handle the error.

5️⃣ Multiple exceptions

Write one program that can raise:

ValueError

ZeroDivisionError

Handle both.

# %%
Write a program that takes two numbers and prints division.
If denominator is zero, print "Cannot divide by zero".

# %%
try:
    a=int(input())
    b=int(input())
    divi=a/b
except Exception as e:
    print("there is error")
# Out:
#  2
#  1

# %%
Take an integer from user.
If user enters a string, print "Enter valid number".

# %%
try:
    a=int(input())
except Exception as e:
    print("string format not allowed")
else:
    print("your code has run sucsessfully:")
# Out:
#  ji
# string format not allowed

# %%
#Access index 5 from a list of 3 elements.
#Handle the exception.
list1=[12,2,3]
try:
    a=list1[5]
    print(a)
except Exception as e:
    print("invalid index")
# Out:
# invalid index

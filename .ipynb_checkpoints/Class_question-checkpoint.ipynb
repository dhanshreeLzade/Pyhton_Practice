# %%
#write a for loop to print all days of weeks
days=('Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday')
for i in days:
    print(i)
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#ask user to enter name and print each chracter seprately
user=input("enter the name: ")
for i in user:
    print(i,sep=",",end=" ")
# Out:
# enter the name:  heena
# h e e n a

# %%
#find total sales using for loop
sales=[12000,15000,10000,18000]
sum=0
for i in sales:
    sum=i+sum
print(sum)
# Out:
# 55000

# %%
12000+15000+10000+18000
# Out:
# 55000

# %%
#write a while loop that keeps asking for pin until the correct pin (1234) is entered
i=0
while i<=1000:
    user_pin=int(input("enter pin"))
    if user_pin==1234:
        print("you have stop the loop")
        break
# Out:
# enter pin 352
# enter pin 32
# enter pin 34
# enter pin 45
# enter pin 52
# enter pin 1234
# you have stop the loop

# %%
#tank fills 10 liters at a time start from 0 and keep adding 10 until it raches 100 liters

# %%
tank=0
for i in range(1,100):
    if tank<100:
        tank=10+tank
        print("liters adding: ",tank)
        break
print("Tank is full")
# Out:
# liters adding:  10
# Tank is full

# %%
tank = 0
while tank <= 100:
    print("liters addinng here is",tank,)
    tank = tank + 10
    break
print("Tank is full")
# Out:
# liters addinng here is 0
# Tank is full

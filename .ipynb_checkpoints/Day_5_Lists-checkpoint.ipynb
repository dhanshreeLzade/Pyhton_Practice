# %%
#insert -- index through add elements
#append -- elements add from end
#extend -- values add through list 
""" list2.insert(index,"values")
list2.append(100) -- add at the end
list2.extend() -- when we want to add 2 lists
list.extend(list2)
remove methods
remove
pop
del
list.remove("dev") ----  removes by values
list.pop(6) --- removes via index
list.del[6] -- removes via index but written in []brackets .
 del list[6] --- index in [] 
 list2.clear() -- clears whole list
 list2.sort() -- to sort elements  
 # when we sort it should be all integers or strings
 list2.sort(reverse= True) to reverse the list 
 list2[4] =155 --- when we want to replace value rather than just insert or put
 
 
 










"""
# Out:
# ' list2.insert(index,"values")\nlist2.append(100) -- add at the end\nlist2.extend() -- when we want to add 2 lists\nlist.extend(list2)\nremove methods\nremove\npop\ndel\nlist.remove("dev") ----  removes by values\nlist.pop(6) --- removes via index\nlist.del[6] -- removes via index but written in []brackets .\n del list[6] --- index in [] \n list2.clear() -- clears whole list\n list2.sort() -- to sort elements  \n # when we sort it should be all integers or strings\n list2.sort(reverse= True) to reverse the list \n list2[4] =155 --- when we want to replace value rather than just insert or put\n \n \n \n\n\n\n\n\n\n\n\n\n\n'

# %% [markdown]
# # List - collection of items store in single variable........

# %%
a=[]
a
# Out:
# []

# %%
# Out:
# False

# %%
a=[1,2,3]
a
# Out:
# [1, 2, 3]

# %%
type(a)
# Out:
# list

# %%
# tuple

# %%
list1=[12,"rajesh","moss-tech",[3,'ritesh',90,90,'RTO'],[90,45,["raj"]],["pratiksha","deveshri"],"dhanashri",7]
print(list1[4][2][0])
# Out:
# raj

# %%
list1print(list1[4][2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 list1print(list1[4][2])
#
# NameError: name 'list1print' is not defined

# %%
list1=[12,"rajesh","moss-tech",[3,'ritesh',90,90,'RTO'],[90,45,"raj"],["pratiksha","deveshri"],"dhanashri",7]
 list1.replace([4][3],"hey")
# Out:
#   Cell In[4], line 2
#     list1.replace([4][3],"hey")
#     ^
# IndentationError: unexpected indent

# %%
list1=[12,"rajesh","moss-tech",[3,'ritesh',90,90,'RTO'],[90,45,["raj"]],["pratiksha","deveshri"],"dhanashri",7]
#list1[4][3]=1
list1[4][2][0]=1
print(list1)
# Out:
# [12, 'rajesh', 'moss-tech', [3, 'ritesh', 90, 90, 'RTO'], [90, 45, [1]], ['pratiksha', 'deveshri'], 'dhanashri', 7]

# %%
"""
a=int(input("enter")) -- deafult it will trake type as string bu here int
a=[] empty
list add elemets here
a=input("enter")
a.append("2")
print(a)



"""
# Out:
# '\na=int(input("enter")) -- deafult it will trake type as string bu here int\na=[] empty\nlist add elemets here\na=input("enter")\na.append("2")\nprint(a)\n\n\n\n'

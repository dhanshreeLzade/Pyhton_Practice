# %%
"""#operator
#a!=b
#x=5
#y=6
a=true
b=true
print(a and b)
a= false
b=true
print(a and b)
a=true
b-false
print(a and b)

a=true
b=true
print(a or b)

a=true
b=false
print(a or b)

a=false
 b=true
 print(a or b)

a=true
print(not a)

a=6
b=5
print(a and b)

a=4
b=5
print(print a or b)

a=3
b=6
print (a or b)

 count= int(input("enter the count: "))
 thesum=int(input("Enter the sum  "))
 if count>0 and thesum //count >10:
 print(average >10)
 else:
 print("count=0 or average <=10)


per=int(input("enter the number:" ))
if per <35 :
print ("fail")
else
print("pass")


#sign
emil_id=abc@gmail.com
pass_id="pass@123
#login
emil_id_new=input("enter")
pass_new=input("enter")
if emil_id



"""
# Out:
# '#operator\n#a!=b\n#x=5\n#y=6\na=true\nb=true\nprint(a and b)\na= false\nb=true\nprint(a and b)\na=true\nb-false\nprint(a and b)\n\na=true\nb=true\n\n\n\n\n\n\n\n\n\n\n'

# %% [markdown]
# # Calculator

# %%
Input1=32 #Input
Input2=23 #Input

Add=Input1+Input2
Sub=Input1-Input2
Multiply=Input1*Input2
Div=Input1/Input2  # Note- Input1/Input2 can give values in floating points if we dont want that then we can simply use Input1//Input2 for only integer value.
Mod=Input1%Input2  # Note- In normal calsi value will be different as it gives %(percentage) & in languages it means % (modulus) which is remainder of values.
Mod                #This will not print.
print("Addition")
print(Input1,"+",Input2,"=",Add)
print("Substraction")
print(Input1,"+",Input2,"=",Sub)
print("Multiplication")
print(Input1,"+",Input2, "=",Multiply)
print("Division")
print(Input1,"+",Input2, "=",Div)
print("Modulus")
print(Input1,"+",Input2,"=",Mod)
Add                #Variable at the end will print with name if we want to print other 1 in that case we have to write print statement.
# Out:
# Addition
# 32 + 23 = 55
# Substraction
# 32 + 23 = 9
# Multiplication
# 32 + 23 = 736
# Division
# 32 + 23 = 1.391304347826087
# Modulus
# 32 + 23 = 9
# 55
